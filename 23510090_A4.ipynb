# %%
import os
import glob
import PyPDF2
import pandas as pd
from collections import Counter, defaultdict
from nltk.util import ngrams
import re

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as f:
        reader = PyPDF2.PdfReader(f)
        for page in reader.pages:
            text += page.extract_text() or ""
    return text

# %%
def tokenize(text):
    # regex tokenizer (safer than nltk.word_tokenize)
    return re.findall(r'\b[a-zA-Z]+\b', text.lower())

# %%
def generate_ngrams(tokens, n):
    return [' '.join(gram) for gram in ngrams(tokens, n)]

# %%
pdf_folder = "batchspdf/"
pdf_files = glob.glob(os.path.join(pdf_folder, "*.pdf"))
csv_folder = "csv/"   # subfolder for saving CSVs   
os.makedirs(csv_folder, exist_ok=True)

# %%
aggregate_counts = defaultdict(lambda: {"total_freq": 0, "doc_count": 0})

# %%
for pdf in pdf_files:
    text = extract_text_from_pdf(pdf)
    tokens = tokenize(text)
    
    # per-document counters
    doc_counters = {
        "unigrams": Counter(tokens),
        "bigrams": Counter(generate_ngrams(tokens, 2)),
        "trigrams": Counter(generate_ngrams(tokens, 3)),
        "quadgrams": Counter(generate_ngrams(tokens, 4))
    }
    
    # update aggregate
    for category, counter in doc_counters.items():
        for term, freq in counter.items():
            aggregate_counts[(category, term)]["total_freq"] += freq
            aggregate_counts[(category, term)]["doc_count"] += 1
    
    # save per-document CSV
    rows_doc = []
    for category, counter in doc_counters.items():
        for term, freq in counter.items():
            rows_doc.append([category, term, freq])
    df_doc = pd.DataFrame(rows_doc, columns=["Category", "Term", "Frequency"])
    pdf_name = os.path.basename(pdf).replace(".pdf", "")
    df_doc.to_csv(os.path.join(csv_folder, f"{pdf_name}_ngrams.csv"), index=False)
# Out:
# ---------------------------------------------------------------------------
# PdfReadError                              Traceback (most recent call last)
# Cell In[7], line 2
#       1 for pdf in pdf_files:
# ----> 2     text = extract_text_from_pdf(pdf)
#       3     tokens = tokenize(text)
#       5     # per-document counters
#
# Cell In[2], line 6, in extract_text_from_pdf(pdf_path)
#       4     reader = PyPDF2.PdfReader(f)
#       5     for page in reader.pages:
# ----> 6         text += page.extract_text() or ""
#       7 return text
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python313\Lib\site-packages\PyPDF2\_page.py:1851, in PageObject.extract_text(self, Tj_sep, TJ_sep, orientations, space_width, visitor_operand_before, visitor_operand_after, visitor_text, *args)
#    1848 if isinstance(orientations, int):
#    1849     orientations = (orientations,)
# -> 1851 return self._extract_text(
#    1852     self,
#    1853     self.pdf,
#    1854     orientations,
#    1855     space_width,
#    1856     PG.CONTENTS,
#    1857     visitor_operand_before,
#    1858     visitor_operand_after,
#    1859     visitor_text,
#    1860 )
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python313\Lib\site-packages\PyPDF2\_page.py:1356, in PageObject._extract_text(self, obj, pdf, orientations, space_width, content_key, visitor_operand_before, visitor_operand_after, visitor_text)
#    1352     content = (
#    1353         obj[content_key].get_object() if isinstance(content_key, str) else obj
#    1354     )
#    1355     if not isinstance(content, ContentStream):
# -> 1356         content = ContentStream(content, pdf, "bytes")
#    1357 except KeyError:  # it means no content can be extracted(certainly empty page)
#    1358     return ""
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python313\Lib\site-packages\PyPDF2\generic\_data_structures.py:867, in ContentStream.__init__(self, stream, pdf, forced_encoding)
#     865 data = b""
#     866 for s in stream:
# --> 867     data += b_(s.get_object().get_data())
#     868     if len(data) == 0 or data[-1] != b"\n":
#     869         data += b"\n"
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python313\Lib\site-packages\PyPDF2\generic\_data_structures.py:827, in EncodedStreamObject.get_data(self)
#     823 else:
#     824     # create decoded object
#     825     decoded = DecodedStreamObject()
# --> 827     decoded._data = decode_stream_data(self)
#     828     for key, value in list(self.items()):
#     829         if key not in (SA.LENGTH, SA.FILTER, SA.DECODE_PARMS):
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python313\Lib\site-packages\PyPDF2\filters.py:529, in decode_stream_data(stream)
#     527     data = ASCIIHexDecode.decode(data)  # type: ignore
#     528 elif filter_type in (FT.LZW_DECODE, FTA.LZW):
# --> 529     data = LZWDecode.decode(data, stream.get(SA.DECODE_PARMS))  # type: ignore
#     530 elif filter_type in (FT.ASCII_85_DECODE, FTA.A85):
#     531     data = ASCII85Decode.decode(data)
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python313\Lib\site-packages\PyPDF2\filters.py:334, in LZWDecode.decode(data, decode_parms, **kwargs)
#     332     deprecate_with_replacement("decodeParms", "parameters", "4.0.0")
#     333     decode_parms = kwargs["decodeParms"]  # noqa: F841
# --> 334 return LZWDecode.Decoder(data).decode()
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python313\Lib\site-packages\PyPDF2\filters.py:295, in LZWDecode.Decoder.decode(self)
#     293 cW = self.next_code()
#     294 if cW == -1:
# --> 295     raise PdfReadError("Missed the stop code in LZWDecode!")
#     296 if cW == self.STOP:
#     297     break
#
# PdfReadError: Missed the stop code in LZWDecode!

# %%
rows = []
for (category, term), data in aggregate_counts.items():
    total = data["total_freq"]
    docs = data["doc_count"]
    avg = total / docs if docs > 0 else 0
    rows.append([category, term, total, docs, avg])

df = pd.DataFrame(rows, columns=["Category", "Term", "Total_Frequency", "Doc_Count", "Avg_Freq_per_Doc"])
df.to_csv(os.path.join(csv_folder, "ngrams_summary.csv"), index=False)

print(df)
# Out:
#         Category                                  Term  Total_Frequency  \
# 0       unigrams                                 ipynb               38
# 1       unigrams                          colaboratory               38
# 2       unigrams                                 https               81
# 3       unigrams                                 colab               39
# 4       unigrams                              research               47
# ...          ...                                   ...              ...
# 59337  quadgrams                 to get required value                1
# 59338  quadgrams               get required value thus                1
# 59339  quadgrams          required value thus standard                1
# 59340  quadgrams          value thus standard sampling                1
# 59341  quadgrams  thus standard sampling distributions                1
#
#        Doc_Count  Avg_Freq_per_Doc
# 0              1         38.000000
# 1              1         38.000000
# 2              6         13.500000
# 3              1         39.000000
# 4              3         15.666667
# ...          ...               ...
# 59337          1          1.000000
# 59338          1          1.000000
# 59339          1          1.000000
# 59340          1          1.000000
# 59341          1          1.000000
#
# [59342 rows x 5 columns]
