# %%
# Plotting the distributions after normalization
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(N_max_divide[:,0], bins=50, density=True, alpha=0.6, color='g', label='Normalized Normal')
plt.title('Normalized Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density x')
plt.subplot(1, 3, 2)
plt.hist(P_max_divide[:,0], bins=50, density=True, alpha=0.6, color='b', label='Normalized Power Law')
plt.title('Normalized Power Law Distribution')
plt.xlabel('Value')
plt.ylabel('Density x')
plt.subplot(1, 3, 3)
plt.hist(G_max_divide[:,0], bins=50, density=True, alpha=0.6, color='r', label='Normalized Geometric')
plt.title('Normalized Geometric Distribution')
plt.xlabel('Value')
plt.ylabel('Density x')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(N_max_divide[:,1], bins=50, density=True, alpha=0.6, color='g', label='Normalized Normal')
plt.title('Normalized Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density y')
plt.subplot(1, 3, 2)
plt.hist(P_max_divide[:,1], bins=50, density=True, alpha=0.6, color='b', label='Normalized Power Law')
plt.title('Normalized Power Law Distribution')
plt.xlabel('Value')
plt.ylabel('Density y')
plt.subplot(1, 3, 3)
plt.hist(G_max_divide[:,1], bins=50, density=True, alpha=0.6, color='r', label='Normalized Geometric')
plt.title('Normalized Geometric Distribution')
plt.xlabel('Value')
plt.ylabel('Density y')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(N_max_divide[:,2], bins=50, density=True, alpha=0.6, color='g', label='Normalized Normal')
plt.title('Normalized Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density z')
plt.subplot(1, 3, 2)
plt.hist(P_max_divide[:,2], bins=50, density=True, alpha=0.6, color='b', label='Normalized Power Law')
plt.title('Normalized Power Law Distribution')
plt.xlabel('Value')
plt.ylabel('Density z')
plt.subplot(1, 3, 3)
plt.hist(G_max_divide[:,2], bins=50, density=True, alpha=0.6, color='r', label='Normalized Geometric')
plt.title('Normalized Geometric Distribution')
plt.xlabel('Value')
plt.ylabel('Density z')
plt.tight_layout()
plt.show()

datasets = [N_max_divide, P_max_divide, G_max_divide]
colors = ['g', 'b', 'r']
labels = ['Normal', 'Power Law', 'Geometric']
dims = ['x', 'y', 'z']

for i in range(3):  # For each dimension
    plt.figure(figsize=(12, 4))
    for j in range(3):  # For each dataset
        plt.subplot(1, 3, j + 1)
        plt.hist(datasets[j][:, i], bins=50, density=True, alpha=0.6,
                 color=colors[j], label=f'Normalized {labels[j]}')
        plt.title(f'Normalized {labels[j]} Distribution')
        plt.xlabel('Value')
        plt.ylabel(f'Density {dims[i]}')
        plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# Plotting the distributions after normalization using sum
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)  
plt.hist(N_sum_divide[:,0], bins=50, density=True, alpha=0.6, color='g', label='Sum Normalized Normal')
plt.title('Sum Normalized Normal Distribution') 
plt.xlabel('Value')
plt.ylabel('Density x')
plt.subplot(1, 3, 2)
plt.hist(P_sum_divide[:,0], bins=50, density=True, alpha=0.6, color='b', label='Sum Normalized Power Law')
plt.title('Sum Normalized Power Law Distribution')
plt.xlabel('Value')
plt.ylabel('Density x')
plt.subplot(1, 3, 3)
plt.hist(G_sum_divide[:,0], bins=50, density=True, alpha=0.6, color='r', label='Sum Normalized Geometric')
plt.title('Sum Normalized Geometric Distribution')
plt.xlabel('Value')
plt.ylabel('Density x')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)  
plt.hist(N_sum_divide[:,1], bins=50, density=True, alpha=0.6, color='g', label='Sum Normalized Normal')
plt.title('Sum Normalized Normal Distribution') 
plt.xlabel('Value')
plt.ylabel('Density y')
plt.subplot(1, 3, 2)
plt.hist(P_sum_divide[:,1], bins=50, density=True, alpha=0.6, color='b', label='Sum Normalized Power Law')
plt.title('Sum Normalized Power Law Distribution')
plt.xlabel('Value')
plt.ylabel('Density y')
plt.subplot(1, 3, 3)
plt.hist(G_sum_divide[:,1], bins=50, density=True, alpha=0.6, color='r', label='Sum Normalized Geometric')
plt.title('Sum Normalized Geometric Distribution')
plt.xlabel('Value')
plt.ylabel('Density y')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)  
plt.hist(N_sum_divide[:,2], bins=50, density=True, alpha=0.6, color='g', label='Sum Normalized Normal')
plt.title('Sum Normalized Normal Distribution') 
plt.xlabel('Value')
plt.ylabel('Density z')
plt.subplot(1, 3, 2)
plt.hist(P_sum_divide[:,2], bins=50, density=True, alpha=0.6, color='b', label='Sum Normalized Power Law')
plt.title('Sum Normalized Power Law Distribution')
plt.xlabel('Value')
plt.ylabel('Density z')
plt.subplot(1, 3, 3)
plt.hist(G_sum_divide[:,2], bins=50, density=True, alpha=0.6, color='r', label='Sum Normalized Geometric')
plt.title('Sum Normalized Geometric Distribution')
plt.xlabel('Value')
plt.ylabel('Density z')
plt.tight_layout()
plt.show()


datasets = [N_sum_divide, P_sum_divide, G_sum_divide]
labels = ['Normal', 'Power Law', 'Geometric']
colors = ['g', 'b', 'r']
dims = ['x', 'y', 'z']

for i in range(3):  # Loop over dimensions
    plt.figure(figsize=(12, 4))
    for j in range(3):  # Loop over datasets
        plt.subplot(1, 3, j + 1)
        plt.hist(datasets[j][:, i], bins=50, density=True, alpha=0.6,
                 color=colors[j], label=f'Sum Normalized {labels[j]}')
        plt.title(f'Sum Normalized {labels[j]} Distribution')
        plt.xlabel('Value')
        plt.ylabel(f'Density {dims[i]}')
        # plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# Percentile Normalization

plt.figure(figsize=(16,4))
plt.suptitle('Percentiles of Normal Distribution')

plt.subplot(1, 3, 1)
plt.plot(N_x_percentiles, N[:,0], 'o', label='Normal x Percentiles')
plt.xlabel('Percentiles')
plt.ylabel('Values')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(N_y_percentiles, N[:,1], 'o', label='Normal y Percentiles')
plt.xlabel('Percentiles')
plt.ylabel('Values')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(N_z_percentiles, N[:,2], 'o', label='Normal z Percentiles')
plt.xlabel('Percentiles')
plt.ylabel('Values')
plt.legend()
plt.tight_layout()
plt.show()

# Assuming N is already defined and has shape (10000, 3)
n_samples = N.shape[0]
percentiles = []

for i in range(3):
    ranks = rankdata(N[:, i], method='average')
    p = 100 * (ranks - 1) / (n_samples - 1)
    percentiles.append(p)

plt.figure(figsize=(16, 4))
plt.suptitle('Percentiles of Normal Distribution')

for i, axis in enumerate(['x', 'y', 'z']):
    plt.subplot(1, 3, i+1)
    plt.plot(percentiles[i], N[:, i], 'o', label=f'Normal {axis} Percentiles', markersize=2)
    plt.xlabel('Percentiles')
    plt.ylabel('Values')
    plt.legend()

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Leave space for suptitle
plt.show()

# %%
labels1 = ['Normal x','Normal y','Normal z']
labels2 = ['Power Law x','Power Law y','Power Law z']
labels3 = ['Geometric x','Geometric y','Geometric z']

# Plot
plt.figure(figsize=(12,6))
plt.boxplot([N[:,0],N[:,1],N[:,2]], tick_labels=labels1)
plt.title('Boxplot of Distributions for Normal Distribution')
plt.ylabel('Values')
plt.grid(axis='y')
plt.show()

plt.figure(figsize=(12,6))
plt.boxplot([P[:,0],P[:,1],P[:,2]], tick_labels=labels2)
plt.title('Boxplot of Distributions for Power Law Distribution')   
plt.ylabel('Values')
plt.grid(axis='y')
plt.show()

plt.figure(figsize=(12,6))
plt.boxplot([G[:,0],G[:,1],G[:,2]], tick_labels=labels3)
plt.title('Boxplot of Distributions for Geometric Distribution')
plt.ylabel('Values')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12,4 ))
plt.subplot(1, 3, 1)
plt.hist(N[:,0], bins=50, density=True, alpha=0.6, color='g')
plt.title('Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density x')
plt.axvline(np.mean(N[:,0]), color='k', linestyle='dashed', linewidth=1, label='Mean')
plt.subplot(1, 3, 2)
plt.hist(P[:,0], bins=50, density=True, alpha=0.6, color='b')
plt.title('Power Law Distribution')
plt.xlabel('Value')
plt.ylabel('Density x')
plt.subplot(1, 3, 3)
plt.hist(G[:,0], bins=50, density=True, alpha=0.6, color='r')
plt.title('Geometric Distribution')
plt.xlabel('Value')
plt.ylabel('Density x')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12,4 ))
plt.subplot(1, 3, 1)
plt.hist(N[:,1], bins=50, density=True, alpha=0.6, color='g')
plt.title('Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density y')
plt.subplot(1, 3, 2)
plt.hist(P[:,1], bins=50, density=True, alpha=0.6, color='b')
plt.title('Power Law Distribution')
plt.xlabel('Value')
plt.ylabel('Density y')
plt.subplot(1, 3, 3)
plt.hist(G[:,1], bins=50, density=True, alpha=0.6, color='r')
plt.title('Geometric Distribution')
plt.xlabel('Value')
plt.ylabel('Density y')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12,4 ))
plt.subplot(1, 3, 1)
plt.hist(N[:,2], bins=50, density=True, alpha=0.6, color='g')
plt.title('Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density z')
plt.subplot(1, 3, 2)
plt.hist(P[:,2], bins=50, density=True, alpha=0.6, color='b')
plt.title('Power Law Distribution')
plt.xlabel('Value')
plt.ylabel('Density z')
plt.subplot(1, 3, 3)
plt.hist(G[:,2], bins=50, density=True, alpha=0.6, color='r')
plt.title('Geometric Distribution')
plt.xlabel('Value')
plt.ylabel('Density z')
plt.tight_layout()
plt.show()

# Assuming N, P, G are defined and of shape (n_samples, 3)
distributions = [N, P, G]
titles = ['Normal', 'Power Law', 'Geometric']
colors = ['g', 'b', 'r']
axes = ['x', 'y', 'z']

for dim in range(3):
    plt.figure(figsize=(12, 4))
    for i in range(3):
        plt.subplot(1, 3, i + 1)
        plt.hist(distributions[i][:, dim], bins=50, density=True, alpha=0.6, color=colors[i])
        plt.title(f'{titles[i]} Distribution')
        plt.xlabel('Value')
        plt.ylabel(f'Density {axes[dim]}')
        plt.axvline(np.mean(distributions[i][:, dim]), color='k', linestyle='dashed', linewidth=1, label='Mean')
    plt.tight_layout()
    plt.show()

# %%
# Plotting the distributions after normalization using z-score
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)  
plt.hist(n_z[:,0], bins=50, density=True, alpha=0.6, color='g', label='Z Normalized Normal')
plt.title('Z Normalized Normal Distribution') 
plt.xlabel('Value')
plt.ylabel('Density x')
plt.subplot(1, 3, 2)
plt.hist(p_z[:,0], bins=50, density=True, alpha=0.6, color='b', label='Z Normalized Power Law')
plt.title('Z Normalized Power Law Distribution')
plt.xlabel('Value')
plt.ylabel('Density x')
plt.subplot(1, 3, 3)
plt.hist(g_z[:,0], bins=50, density=True, alpha=0.6, color='r', label='Z Normalized Geometric')
plt.title('Z Normalized Geometric Distribution')
plt.xlabel('Value')
plt.ylabel('Density x')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)  
plt.hist(n_z[:,1], bins=50, density=True, alpha=0.6, color='g', label='Z Normalized Normal')
plt.title('Z Normalized Normal Distribution') 
plt.xlabel('Value')
plt.ylabel('Density ')
plt.subplot(1, 3, 2)
plt.hist(p_z[:,1], bins=50, density=True, alpha=0.6, color='b', label='Z Normalized Power Law')
plt.title('Z Normalized Power Law Distribution')
plt.xlabel('Value')
plt.ylabel('Density y')
plt.subplot(1, 3, 3)
plt.hist(g_z[:,1], bins=50, density=True, alpha=0.6, color='r', label='Z Normalized Geometric')
plt.title('Z Normalized Geometric Distribution')
plt.xlabel('Value')
plt.ylabel('Density y')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)  
plt.hist(n_z[:,2], bins=50, density=True, alpha=0.6, color='g', label='Z Normalized Normal')
plt.title('Z Normalized Normal Distribution') 
plt.xlabel('Value')
plt.ylabel('Density z')
plt.subplot(1, 3, 2)
plt.hist(p_z[:,2], bins=50, density=True, alpha=0.6, color='b', label='Z Normalized Power Law')
plt.title('Z Normalized Power Law Distribution')
plt.xlabel('Value')
plt.ylabel('Density z')
plt.subplot(1, 3, 3)
plt.hist(g_z[:,2], bins=50, density=True, alpha=0.6, color='r', label='Z Normalized Geometric')
plt.title('Z Normalized Geometric Distribution')
plt.xlabel('Value')
plt.ylabel('Density z')
plt.tight_layout()
plt.show()


datasets = [n_z, p_z, g_z]
colors = ['g', 'b', 'r']
titles = ['Normal', 'Power Law', 'Geometric']

for col in range(3):  # For each column (x, y, z)
    plt.figure(figsize=(12, 4))
    for i, data in enumerate(datasets):
        plt.subplot(1, 3, i+1)
        plt.hist(data[:, col], bins=50, density=True, alpha=0.6, color=colors[i], label=f'Z Normalized {titles[i]}')
        plt.title(f'Z Normalized {titles[i]} Distribution')
        plt.xlabel('Value')
        plt.ylabel('Density')
        plt.legend()
    plt.tight_layout()
    plt.show()
