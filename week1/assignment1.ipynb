# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gmean
import math

# %%
def min_var_change_count(k, N):
    var_change_counts = []

    for _ in range(k):
        array = np.random.normal(size=N,loc=0, scale=0.000000001 )  # Normal distribution with mean=0, std=1
        # array = np.random.randint(0, 100, size=N)  # Random integers in [0, 100)
        temp_min = float('inf')
        var_change_count = 0
        i = 0
        while i < N:
            if array[i] < temp_min:
                temp_min = array[i]
                var_change_count += 1
            i += 1
        var_change_counts.append(var_change_count)

    
    plt.hist(var_change_counts, bins=20, edgecolor='black',color = "red")
    plt.title(f'Histogram of var_change_count (N={N})')
    plt.xlabel('var_change_count')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

    
    mean_vcc = np.mean(var_change_counts)
    median_vcc = np.median(var_change_counts)
    geo_mean_vcc = gmean(var_change_counts)
    std_dev_vcc = np.std(var_change_counts)

    print(f"N = {N}")
    print(f"Mean: {mean_vcc}")
    print(f"Median: {median_vcc}")
    print(f"Geometric Mean: {geo_mean_vcc}")

    return mean_vcc, std_dev_vcc

# %%
N_values = [10, 20, 50, 100, 200, 500, 1000, 2000, 5000,
            10000, 20000, 50000, 100000, 200000, 500000, 1000000]
# ,5000000, 10000000, 20000000, 50000000, 100000000]

# %%
mean_vcc_list = []

for N in N_values:
    mean_vcc,std_dev = min_var_change_count(100, N)
    mean_vcc_list.append(mean_vcc)
# Out:
# N = 10
# Mean: 2.72
# Median: 2.0
# Geometric Mean: 2.4763009431314433
# N = 20
# Mean: 3.54
# Median: 3.0
# Geometric Mean: 3.1809726096699813
# N = 50
# Mean: 4.44
# Median: 4.0
# Geometric Mean: 4.13245104740649
# N = 100
# Mean: 5.03
# Median: 5.0
# Geometric Mean: 4.624417849269569
# N = 200
# Mean: 5.94
# Median: 6.0
# Geometric Mean: 5.666122376894202
# N = 500
# Mean: 6.67
# Median: 6.5
# Geometric Mean: 6.261568906288445
# N = 1000
# Mean: 7.04
# Median: 7.0
# Geometric Mean: 6.651730114262139
# N = 2000
# Mean: 8.02
# Median: 8.0
# Geometric Mean: 7.560620501613633
# N = 5000
# Mean: 8.84
# Median: 9.0
# Geometric Mean: 8.380646797416345
# N = 10000
# Mean: 9.76
# Median: 9.5
# Geometric Mean: 9.248329877613559
# N = 20000
# Mean: 10.63
# Median: 11.0
# Geometric Mean: 10.114390054580202
# N = 50000
# Mean: 11.04
# Median: 10.5
# Geometric Mean: 10.671583415629273
# N = 100000
# Mean: 11.92
# Median: 11.5
# Geometric Mean: 11.431932805454274
# N = 200000
# Mean: 12.54
# Median: 13.0
# Geometric Mean: 12.088467942203208
# N = 500000
# Mean: 13.47
# Median: 13.0
# Geometric Mean: 13.03734977829369
# N = 1000000
# Mean: 14.89
# Median: 15.0
# Geometric Mean: 14.547276080483133

# %%
for i in range(len(mean_vcc_list)):
    print(f"N = {N_values[i]}, Mean var_change_count = {mean_vcc_list[i]}")
# Out:
# N = 10, Mean var_change_count = 2.72
# N = 20, Mean var_change_count = 3.54
# N = 50, Mean var_change_count = 4.44
# N = 100, Mean var_change_count = 5.03
# N = 200, Mean var_change_count = 5.94
# N = 500, Mean var_change_count = 6.67
# N = 1000, Mean var_change_count = 7.04
# N = 2000, Mean var_change_count = 8.02
# N = 5000, Mean var_change_count = 8.84
# N = 10000, Mean var_change_count = 9.76
# N = 20000, Mean var_change_count = 10.63
# N = 50000, Mean var_change_count = 11.04
# N = 100000, Mean var_change_count = 11.92
# N = 200000, Mean var_change_count = 12.54
# N = 500000, Mean var_change_count = 13.47
# N = 1000000, Mean var_change_count = 14.89

# %%
# plt.figure(figsize=(10, 6))
N_values_log = np.log10(N_values)

plt.figure(figsize=(20, 12))
plt.plot(N_values, mean_vcc_list, marker='o', color='red')
plt.plot(N_values, N_values_log, marker='o', color='blue')
plt.xscale('log', base=10)
plt.xlabel('Array Size N')
# plt.xticks(N_values, rotation=45)
plt.ylabel('Mean var_change_count')
plt.title('N vs Mean var_change_count')
plt.grid(True)
plt.show()

# %% [markdown]
# <!-- plt.figure(figsize=(20, 12))
# plt.scatter(N_values, mean_vcc_list, color='red', s=100)
# plt.xscale('log', base=10)
# plt.xlabel('Array Size N (log scale)')
# plt.ylabel('Mean var_change_count')
# plt.title('Scatter Plot: N vs Mean var_change_count')
# plt.grid(True)
# plt.show() -->
